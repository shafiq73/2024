# %% [markdown]
# <a href="https://colab.research.google.com/github/shafiq73/2024/blob/main/Texidermy_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
html_code = """
<!DOCTYPE html>
<html lang="en">
<head>
<meta charset="UTF-8">
<title>Taxidermy Studio</title>

<style>

body{
font-family: Arial;
margin:0;
background:#f4f4f4;
}

header{
background:#111;
color:white;
padding:20px;
text-align:center;
}

nav{
background:#333;
padding:10px;
text-align:center;
}

nav a{
color:white;
margin:15px;
text-decoration:none;
font-size:18px;
}

.hero{
background:url('https://images.unsplash.com/photo-1601758123927-196e0f0f5f1c');
height:400px;
background-size:cover;
color:white;
display:flex;
justify-content:center;
align-items:center;
font-size:40px;
}

.section{
padding:40px;
text-align:center;
}

.cards{
display:flex;
justify-content:center;
gap:20px;
}

.card{
background:white;
padding:20px;
width:250px;
box-shadow:0 0 10px gray;
}

footer{
background:#111;
color:white;
text-align:center;
padding:20px;
}

</style>
</head>

<body>

<header>
<h1>Premium Taxidermy Studio</h1>
<p>Professional Animal Preservation</p>
</header>

<nav>
<a href="#">Home</a>
<a href="#">Services</a>
<a href="#">Gallery</a>
<a href="#">Contact</a>
</nav>

<div class="hero">
Beautiful Wildlife Art
</div>

<div class="section">
<h2>Our Services</h2>

<div class="cards">

<div class="card">
<h3>Animal Mounting</h3>
<p>Professional taxidermy mounts.</p>
</div>

<div class="card">
<h3>Restoration</h3>
<p>Old mounts restoration service.</p>
</div>

<div class="card">
<h3>Custom Work</h3>
<p>Custom wildlife display designs.</p>
</div>

</div>

</div>

<div class="section">
<h2>Gallery</h2>
<p>Some of our beautiful work.</p>
</div>

<div class="section">
<h2>Contact Us</h2>
<p>Email: info@taxidermy.com</p>
</div>

<footer>
<p>© 2026 Taxidermy Studio</p>
</footer>

</body>
</html>
"""

with open("index.html","w") as f:
    f.write(html_code)

print("Website created successfully!")
# Out:
# Website created successfully!

# %%
# from google.colab import files
# files.download("index.html")

# %%
html_code = """
<!DOCTYPE html>
<html lang="en">
<head>
<meta charset="UTF-8">
<title>Taxidermy Studio</title>
<style>
body{font-family:Arial;margin:0;background:#f4f4f4;}
header{background:#111;color:white;padding:20px;text-align:center;}
nav{background:#333;padding:10px;text-align:center;}
nav a{color:white;margin:15px;text-decoration:none;font-size:18px;}
nav a:hover{color:#ff0;}
.hero{background:url('https://images.unsplash.com/photo-1601758123927-196e0f0f5f1c');height:400px;background-size:cover;color:white;display:flex;justify-content:center;align-items:center;font-size:40px;text-shadow:2px 2px 5px black;}
.section{padding:40px;text-align:center;}
.cards{display:flex;justify-content:center;gap:20px;flex-wrap:wrap;}
.card{background:white;padding:20px;width:250px;box-shadow:0 0 10px gray;}
button{padding:10px 20px;font-size:16px;margin:10px;cursor:pointer;border:none;background:#333;color:white;border-radius:5px;}
button:hover{background:#555;}
img{width:100%;height:auto;border-radius:5px;box-shadow:0 0 5px gray;margin-bottom:10px;}
video{width:100%;max-width:500px;border-radius:5px;margin-bottom:20px;}
footer{background:#111;color:white;text-align:center;padding:20px;}
</style>
</head>
<body>

<header>
<h1>Premium Taxidermy Studio</h1>
<p>Professional Animal Preservation</p>
</header>

<nav>
<a href="#home">Home</a>
<a href="#services">Services</a>
<a href="#gallery">Gallery</a>
<a href="#videos">Videos</a>
<a href="#contact">Contact</a>
</nav>

<div class="hero" id="home">
Beautiful Wildlife Art
</div>

<div class="section" id="services">
<h2>Our Services</h2>
<div class="cards">
<div class="card"><h3>Animal Mounting</h3><p>Professional taxidermy mounts.</p></div>
<div class="card"><h3>Restoration</h3><p>Old mounts restoration service.</p></div>
<div class="card"><h3>Custom Work</h3><p>Custom wildlife display designs.</p></div>
</div>
</div>

<div class="section" id="gallery">
<h2>Gallery</h2>
<p>Click on images to view larger.</p>
<div class="cards">
<img src="https://images.unsplash.com/photo-1592194996308-7b43878e84a6" alt="Wildlife1">
<img src="https://images.unsplash.com/photo-1519681393784-d120267933ba" alt="Wildlife2">
<img src="https://images.unsplash.com/photo-1507525428034-b723cf961d3e" alt="Wildlife3">
</div>
</div>

<div class="section" id="videos">
<h2>Videos</h2>
<button onclick="document.getElementById('video1').scrollIntoView({behavior:'smooth'});">Watch Video 1</button>
<button onclick="document.getElementById('video2').scrollIntoView({behavior:'smooth'});">Watch Video 2</button>

<video id="video1" controls>
<source src="https://www.w3schools.com/html/mov_bbb.mp4" type="video/mp4">
Your browser does not support HTML video.
</video>

<video id="video2" controls>
<source src="https://www.w3schools.com/html/movie.mp4" type="video/mp4">
Your browser does not support HTML video.
</video>
</div>

<div class="section" id="contact">
<h2>Contact Us</h2>
<p>Email: info@taxidermy.com</p>
<p>Phone: +123-456-7890</p>
</div>

<footer>
<p>© 2026 Taxidermy Studio</p>
</footer>

</body>
</html>
"""

# Save as index.html
with open("index.html","w") as f:
    f.write(html_code)

print("✅ Taxidermy website HTML created successfully! Use the next cell to download it.")
# Out:
# ✅ Taxidermy website HTML created successfully! Use the next cell to download it.

# %%
from google.colab import files
files.download("index.html")

# %%
html_code = """
<!DOCTYPE html>
<html lang="en">
<head>
<meta charset="UTF-8">
<title>Professional Taxidermy Studio</title>
<style>
body{font-family:Arial;margin:0;background:#f4f4f4;}
header{background:#111;color:white;padding:20px;text-align:center;}
nav{background:#333;padding:10px;text-align:center;}
nav a{color:white;margin:15px;text-decoration:none;font-size:18px;}
nav a:hover{color:#ff0;}
.hero{background:url('https://images.unsplash.com/photo-1601758123927-196e0f0f5f1c');height:400px;background-size:cover;color:white;display:flex;justify-content:center;align-items:center;font-size:40px;text-shadow:2px 2px 5px black;}
.section{padding:40px;text-align:center;}
.cards{display:flex;justify-content:center;gap:20px;flex-wrap:wrap;}
.card{background:white;padding:20px;width:250px;box-shadow:0 0 10px gray;border-radius:5px;}
button{padding:10px 20px;font-size:16px;margin:10px;cursor:pointer;border:none;background:#333;color:white;border-radius:5px;}
button:hover{background:#555;}
img{width:100%;height:auto;border-radius:5px;box-shadow:0 0 5px gray;margin-bottom:10px;}
video{width:100%;max-width:500px;border-radius:5px;margin-bottom:20px;}
footer{background:#111;color:white;text-align:center;padding:20px;}
input[type="file"]{display:none;}
</style>
</head>
<body>

<header>
<h1>Premium Taxidermy Studio</h1>
<p>Professional Animal Preservation</p>
</header>

<nav>
<a href="#home">Home</a>
<a href="#services">Services</a>
<a href="#gallery">Gallery</a>
<a href="#videos">Videos</a>
<a href="#info">About Taxidermy</a>
<a href="#contact">Contact</a>
</nav>

<div class="hero" id="home">
Masterful Wildlife Art
</div>

<div class="section" id="services">
<h2>Our Services</h2>
<div class="cards">
<div class="card"><h3>Animal Mounting</h3><p>Professional taxidermy mounts for display and education.</p></div>
<div class="card"><h3>Restoration</h3><p>Old mounts restoration to preserve your memories.</p></div>
<div class="card"><h3>Custom Work</h3><p>Custom wildlife display designs for homes or museums.</p></div>
</div>
</div>

<div class="section" id="gallery">
<h2>Gallery</h2>
<p>Upload your images to preview:</p>
<button onclick="document.getElementById('imageUpload').click()">Add Image</button>
<input type="file" id="imageUpload" accept="image/*" multiple>
<div class="cards" id="imageContainer"></div>
</div>

<div class="section" id="videos">
<h2>Videos</h2>
<p>Upload your videos to preview:</p>
<button onclick="document.getElementById('videoUpload').click()">Add Video</button>
<input type="file" id="videoUpload" accept="video/*" multiple>
<div id="videoContainer"></div>
</div>

<div class="section" id="info">
<h2>About Taxidermy</h2>
<p>Taxidermy is the art of preparing, stuffing, and mounting the skins of animals with lifelike effect. It preserves the natural beauty of wildlife for education, research, and display. Proper techniques and experience are crucial for quality work.</p>
</div>

<div class="section" id="contact">
<h2>Contact Us</h2>
<p>Email: info@taxidermy.com</p>
<p>Phone: +123-456-7890</p>
</div>

<footer>
<p>© 2026 Taxidermy Studio</p>
</footer>

<script>
// Image upload preview
document.getElementById('imageUpload').addEventListener('change', function(event){
    const container = document.getElementById('imageContainer');
    container.innerHTML = '';
    Array.from(event.target.files).forEach(file=>{
        const img = document.createElement('img');
        img.src = URL.createObjectURL(file);
        container.appendChild(img);
    });
});

// Video upload preview
document.getElementById('videoUpload').addEventListener('change', function(event){
    const container = document.getElementById('videoContainer');
    container.innerHTML = '';
    Array.from(event.target.files).forEach(file=>{
        const video = document.createElement('video');
        video.controls = true;
        video.src = URL.createObjectURL(file);
        container.appendChild(video);
    });
});
</script>

</body>
</html>
"""

# Save as index.html
with open("index.html","w") as f:
    f.write(html_code)

print("✅ Professional Taxidermy website created! Use next cell to download it.")
# Out:
# ✅ Professional Taxidermy website created! Use next cell to download it.

# %%
from google.colab import files
files.download("index.html")
